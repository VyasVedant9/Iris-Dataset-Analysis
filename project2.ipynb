# %% [markdown]
# # Section 1: Dataset

# %% [markdown]
# I have chosen this dataset which is an iris dataset. I chose this because I have an ardent interest in botany and this dataset will allow me to combine my interests of data science and botany in order to analyse the different features of the different species of irsi flowers such as the setosa, virginica, and the versicolor. I will be analysing features such as the sepal length, sepal width, petal length, petal width for the different species of the flowers. So, let's begin!

# %%
import pandas as pd
df = pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Section 2: Exploratory Data Analysis

# %% [markdown]
# In order to understand the dataset we will find different features of the data set. We will start of by finding the mean for all the four variables. We will then filter the dataset according to the three species which is the setosa, the virginica, and the versicolor. We will then find the mean for each of those dataframes. At the end we will create a cumulative descriptive matrix for each of the variables to see the standard deviation, mean, upper quartile, and lower quartile.

# %% [markdown]
# ### 2.1: Finding the mean for each of the variables

# %%
mean_SepalLength = df["SepalLengthCm"].mean()
mean_SepalLength
# Out:
# 5.843333333333334

# %%
mean_SepalWidth = df["SepalWidthCm"].mean()
mean_SepalWidth
# Out:
# 3.0540000000000003

# %%
mean_PetalLength = df["PetalLengthCm"].mean()
mean_PetalLength
# Out:
# 3.758666666666666

# %%
mean_PetalWidth = df["PetalWidthCm"].mean()
mean_PetalWidth
# Out:
# 1.1986666666666668

# %% [markdown]
# ### 2.2: Finding the Descriptive Statistics for Iris Setosa

# %%
df_setosa = df[df["Species"] == "Iris-setosa"]
df_setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
setosa_SepalLength_mean = df_setosa["SepalLengthCm"].mean()
setosa_SepalLength_mean
# Out:
# 5.006

# %%
setosa_SepalWidth_mean = df_setosa["SepalWidthCm"].mean()
setosa_SepalWidth_mean
# Out:
# 3.418

# %%
setosa_PetalLength_mean = df_setosa["PetalLengthCm"].mean()
setosa_PetalLength_mean
# Out:
# 1.464

# %%
setosa_PetalWidth_mean = df_setosa["PetalWidthCm"].mean()
setosa_PetalWidth_mean
# Out:
# 0.244

# %% [markdown]
# ### 2.3: Finding the descriptive statistics for Iris Virginica

# %%
df_virginica = df[df["Species"] == "Iris-virginica"]
df_virginica
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
virginica_SepalLength_mean = df_virginica["SepalLengthCm"].mean()
virginica_SepalLength_mean
# Out:
# 6.587999999999998

# %%
virginica_SepalWidth_mean = df_virginica["SepalWidthCm"].mean()
virginica_SepalWidth_mean
# Out:
# 2.974

# %%
virginica_PetalLength_mean = df_virginica["PetalLengthCm"].mean()
virginica_PetalLength_mean
# Out:
# 5.5520000000000005

# %%
virginica_PetalWidth_mean = df_virginica["PetalWidthCm"].mean()
virginica_PetalWidth_mean
# Out:
# 2.0260000000000002

# %% [markdown]
# ### 2.4: Finding the Descriptive Statistics for Versicolor

# %%
df_versicolor = df[df["Species"] == "Iris-versicolor"]
df_versicolor
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
versicolor_SepalLength_mean = df_versicolor["SepalLengthCm"].mean()
versicolor_SepalLength_mean
# Out:
# 5.936

# %%
versicolor_SepalWidth_mean = df_versicolor["SepalWidthCm"].mean()
versicolor_SepalWidth_mean
# Out:
# 2.7700000000000005

# %%
versicolor_PetalLength_mean = df_versicolor["PetalLengthCm"].mean()
versicolor_PetalLength_mean
# Out:
# 4.26

# %%
versicolor_PetalWidth_mean = df_versicolor["PetalWidthCm"].mean()
versicolor_PetalWidth_mean
# Out:
# 1.3259999999999998

# %% [markdown]
# ### Cumulative Descriptive Statistics for all the Species and The Whole Dataset

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df_setosa.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
df_virginica.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %%
df_versicolor.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %% [markdown]
# We can see that the sepal length mean is greatest for the virginica species at 6.58, then the versicolor at 5.93 and the setosa at 5.00. The sepal width mean is greatest for the setosa at 3.41, then the virginica at 2.97, and the versicolor at 2.77. The Petal length mean is the greatest for the virginica at 5.55, then the versicolor at 4.26 and the setosa at 1.46. Lastly, the petal width mean is the greatest for virginica at 2.02, the versicolor at 1.32, and the setosa at 0.24

# %% [markdown]
# # Section 3: Exploratory Data Visualization

# %% [markdown]
# ### The Number of Species

# %%
import seaborn as sns
sns.countplot(x = 'Species', data = df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %% [markdown]
# As the bars are approximately of the same height we can conclude that the number of species is equal and the dataset is well balanced with each of the species having a count of 50

# %% [markdown]
# ### Histograms

# %%
df["SepalLengthCm"].hist()
# Out:
# <Axes: >

# %%
df["SepalWidthCm"].hist()
# Out:
# <Axes: >

# %%
df["PetalLengthCm"].hist()
# Out:
# <Axes: >

# %%
df["PetalWidthCm"].hist()
# Out:
# <Axes: >

# %% [markdown]
# The sepal length and the sepal width have curves which form a normal distribution. The Petal length and width have two seperate curves because of the measurement of different species.

# %% [markdown]
# ### Scatter Plots for Each of the Species in terms of sepal length and width

# %%
df_setosa.plot.scatter(x = "SepalLengthCm", y = "SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# As seen in the scatter plot above, the setosa species has a samller sepal length but a higher width.

# %%
df_virginica.plot.scatter(x = "SepalLengthCm", y = "SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# As seen in the scatter plot above, the virginica has smaller sepal widths but larger sepal lengths

# %%
df_versicolor.plot.scatter(x = "SepalLengthCm", y = "SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# As seen in the scatter plot above, the versicolor has almost equal sepal length and sepal width

# %% [markdown]
# ### Scatter Plots for Each Species in Terms of Petal Length and Width

# %%
df_setosa.plot.scatter(x = "PetalLengthCm", y = "PetalWidthCm")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df_virginica.plot.scatter(x = "PetalLengthCm", y = "PetalWidthCm")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df_versicolor.plot.scatter(x = "PetalLengthCm", y = "PetalWidthCm")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# Out of all the three plots seen above and the scales on each axis, it is conveyed that the setosa species has the smallest petal length and width, then is the versicolor species and then the virginica species.

# %% [markdown]
# # Section 4: Data Science

# %% [markdown]
# ### 4.1: Correlation

# %% [markdown]
# The question I have about my dataset is how closely correlated are the factors such as the petal width, petal length, sepal width and the sepal length. In order to understand the correlation between these different factors, I will use the inbuilt function of corr which will give me an output of a correlation matrix. In order to use the corr function I will first filter it to contain only numerical columns. I will interpret the correlation matrix to make inferences about the correlation of the factors stated above.

# %%
numerical_cols = ["Id",	"SepalLengthCm","SepalWidthCm",	"PetalLengthCm"	,"PetalWidthCm"]
df[numerical_cols].corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# These are the main observations I have from the correlation matrix:
# 1. The petal width and sepal length has a strong positive correlation with a correlation coefficient of 0.817954
# 2. The petal width and petal length has a strong positive correlation with a correlation coefficient of 0.962757
# 3. The petal length and sepal length has a strong positive correlation with a correlation coefficient of 0.871754

# %% [markdown]
# ### 4.2: Linear Regression Model

# %% [markdown]
# I will next work on a linear regression model which will have the petal length as the independent variable and the sepal length as the dependent variable.

# %%
from sklearn.linear_model import LinearRegression
df_num = df[numerical_cols]
model = LinearRegression()
model.fit(df_num[["PetalLengthCm"]], df_num["SepalLengthCm"])
df_num["Sepal Length Prediction"] = model.predict(df_num[["PetalLengthCm"]])
df_num["Sepal Length Residue"] = df_num["SepalLengthCm"] - df_num["Sepal Length Prediction"]
df_num
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Sepal Length Prediction  Sepal Length Residue
# 0                   4.878342              0.221658
# 1                   4.878342              0.021658
# ...

# %% [markdown]
# The next linear regression model is a model which will use the petal length as the independent variable and the petal width as the dependent variable.

# %%
model2 = LinearRegression()
model2.fit(df_num[["PetalLengthCm"]], df_num["PetalWidthCm"])
df_num["Petal Width Prediction"] = model2.predict(df_num[["PetalLengthCm"]])
df_num["Petal Width Residue"] = df_num["PetalWidthCm"] - df_num["Petal Width Prediction"]
df_num
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Sepal Length Prediction  Sepal Length Residue  Petal Width Prediction  \
# 0                   4.878342              0.221658                0.216473
# ...

# %% [markdown]
# # Section 5:Overall Summary

# %% [markdown]
# I started off by choosing this dataset as it combines my interest of data science and botany. My main aim while starting off to analyze this dataset was to understand if there was any correlation between the factors such as the sepal length, sepal width, petal length, and petal width. I was also hoping to find out what will be the main differentiating factors between the three types of iris: setosa, virginica, and versicolor. In order to answer these questions, I used different methods to find descriptive statistics, and then use data visualizations, and finally some data science techniques.
#
# To dive deeper, I started off by categorizing the data into three different data frames or datasets based on the iris species, I then used inbuilt functions in the pandas library to find valuable statistical inferences such as the mean, upper and lower quartiles, and the standard deviation. In order to draw conclusions from the data, I used matplotlib in order to create data visualizations which helped me draw inferences from the data. Furthermore, I used a correlation matrix in order to understand the correlation between two variables such as the petal length and the petal width.
#
# My findings from this dataset analysis of iris flower and its species were that the setosa has the smallest petal length and width, and then is the versicolor and then the virginica. The setosa species has a smaller sepal length but a higher width. The virginica has smaller sepal width and larger sepal length. The versicolor has approximately the same sepal length and width. I also found out that the petal width and sepal length have a strong positive correlation. The petal width and petal length have a strong positive correlation. The petal length and sepal length have a strong positive correlation.
